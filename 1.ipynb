# %%
def code():
    string=input('enter:')
   
    print(string)
    words=string.split()
    print(type(words))
    print(words)
    #coding=input(' 1 for coding nad 0 for decoding: ')
    coding= input('1 for coding and 0 for decoding:')
    coding=True if(coding=='1') else False
    if(coding):
        nword=[]
        for word in words:
            if(len(word)>3):
                r1='ahd'
                r2='frg'
                str= r1+word[1:] + word[0]+r2
                nword.append(str)
            else:
                nword.append(word[::-1])
        print(nword)
        print(type(nword))
        print(' '.join(nword))
        
    else:
        nword=[]
        for word in words:
            if(len(word)>3):
                str= word[3:-3]
                str=str[-1]+str[:-1]
                nword.append(str)
            else:
                nword.append(word[::-1])
        print(' '.join(nword))
            

print(code())
#string=input('enter:')words=string.split(' ')nword=[]str=words[1:]nword.append(str)print(type(words))#print(' * '.join(nword))
